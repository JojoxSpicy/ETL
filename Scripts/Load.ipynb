# %% [markdown]
# ### Carga de Datos en la Base de Datos MySQL
#
# Este bloque de código se encarga de cargar el archivo CSV que contiene los datos de los lanzamientos de SpaceX en una base de datos MySQL. Se utiliza **SQLAlchemy** para establecer la conexión y **pandas** para insertar los datos en la tabla correspondiente.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Cargar los datos desde tu archivo CSV en la carpeta 'data'
df = pd.read_csv('../data/spacex_launches_clean.csv')


# Crear una conexión a la base de datos MySQL
engine = create_engine('mysql+pymysql://root:root@localhost/SpaceXData')

# Cargar los datos en la tabla 'launches' de MySQL
df.to_sql('launches', con=engine, if_exists='append', index=False)
# Out:
# 205
